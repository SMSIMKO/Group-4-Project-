# %%
# Initial imports
import pandas as pd # pip instal1 pandas
import numpy as np
import datetime as dt
from pathlib import Path
import os 
import csv
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Reading Unemployment Rate CSV

file_path = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Pre_pandemic_unemploy.csv')

pre_pandemic_unemploy_csv = pd.read_csv(file_path, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pre_pandemic_unemploy_csv.head()
# Out:
#             Pre_Pandemic-Unemploy
# DATE
# 2017-03-01                    4.4
# 2017-04-01                    4.4
# 2017-05-01                    4.4
# 2017-06-01                    4.3
# 2017-07-01                    4.3

# %%
file_path1 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Pandemic_unemploy.csv')
pandemic_unemploy_csv = pd.read_csv(file_path1, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pandemic_unemploy_csv.head()
# Out:
#             Pandemic
# DATE
# 2020-03-01       4.4
# 2020-04-01      14.7
# 2020-05-01      13.2
# 2020-06-01      11.0
# 2020-07-01      10.2

# %%
file_path2 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Post-Pandemic_unemploy.csv')
postpandemic_unemploy_csv = pd.read_csv(file_path2, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

postpandemic_unemploy_csv.head()
# Out:
#             Post_pandemic
# DATE
# 2023-04-01            3.4
# 2023-05-01            3.7
# 2023-06-01            3.6

# %%
df = unemployment_combined = pd.concat([pre_pandemic_unemploy_csv, pandemic_unemploy_csv, postpandemic_unemploy_csv])


unemployment_combined.head(100)
# Out:
#             Pre_Pandemic-Unemploy  Pandemic  Post_pandemic
# DATE
# 2017-03-01                    4.4       NaN            NaN
# 2017-04-01                    4.4       NaN            NaN
# 2017-05-01                    4.4       NaN            NaN
# 2017-06-01                    4.3       NaN            NaN
# 2017-07-01                    4.3       NaN            NaN
# ...                           ...       ...            ...
# 2023-02-01                    NaN       3.6            NaN
# 2023-03-01                    NaN       3.5            NaN
# 2023-04-01                    NaN       NaN            3.4
# 2023-05-01                    NaN       NaN            3.7
# 2023-06-01                    NaN       NaN            3.6
#
# [76 rows x 3 columns]

# %%
#Plot Umemployment rates

unemployment_combined.plot(figsize = (30,20))
# Out:
# <Axes: xlabel='DATE'>

# %%
# Reading Home Price Index CSV
file_path3 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Prepandemic_sales.csv')
prepandemic_sales_csv = pd.read_csv(file_path3, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

prepandemic_sales_csv.head()
# Out:
#             Pre_Pandemic
# DATE
# 2017-01-01       186.802
# 2017-02-01       187.317
# 2017-03-01       187.997
# 2017-04-01       188.734
# 2017-05-01       189.628

# %%
file_path4 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Pandemic_sales.csv')
pandemic_sales_csv = pd.read_csv(file_path4, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pandemic_sales_csv.head()
# Out:
#             Pandemic
# DATE
# 2020-03-01   216.325
# 2020-04-01   216.813
# 2020-05-01   217.122
# 2020-06-01   217.734
# 2020-07-01   219.395

# %%
file_path5 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-U-LOLC/Projects/Stacey_info /Postpandemic_sales.csv')
postpandemic_sales_csv = pd.read_csv(file_path5, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

postpandemic_sales_csv.head()
# Out:
#             Post_Pandemic
# DATE
# 2023-04-01        299.715

# %%
df1 = sales_combined = pd.concat([prepandemic_sales_csv, pandemic_sales_csv, postpandemic_sales_csv])


sales_combined.head(100)
# Out:
#             Pre_Pandemic  Pandemic  Post_Pandemic
# DATE
# 2017-01-01       186.802       NaN            NaN
# 2017-02-01       187.317       NaN            NaN
# 2017-03-01       187.997       NaN            NaN
# 2017-04-01       188.734       NaN            NaN
# 2017-05-01       189.628       NaN            NaN
# ...                  ...       ...            ...
# 2022-12-01           NaN   296.952            NaN
# 2023-01-01           NaN   296.455            NaN
# 2023-02-01           NaN   297.018            NaN
# 2023-03-01           NaN   298.149            NaN
# 2023-04-01           NaN       NaN        299.715
#
# [76 rows x 3 columns]

# %%
#Plot Home sales price Index

df1.plot(kind = "bar", title = "Home Sales Price Index")
f = plt.figure()
f.set_figwidth(200)
f.set_figheight(20)

print("Plot after re-sizing: ")
plt.plot
plt.show()
# Out:
# Plot after re-sizing:
