# %%
# Initial imports
import pandas as pd # pip instal1 pandas
import numpy as np
import datetime as dt
from pathlib import Path
import os 
import csv
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Reading Unemployment Rate CSV

file_path = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/pre_pandemic_unemploy.csv')
pre_pandemic_unemploy_csv = pd.read_csv(file_path, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pre_pandemic_unemploy_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Reading Unemployment Rate CSV
#       3 file_path = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/pre_pandemic_unemploy.csv')
# ----> 4 pre_pandemic_unemploy_csv = pd.read_csv(file_path, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       7 pre_pandemic_unemploy_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
file_path1 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Pandemic_unemploy.csv')
pandemic_unemploy_csv = pd.read_csv(file_path1, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pandemic_unemploy_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 file_path1 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Pandemic_unemploy.csv')
# ----> 2 pandemic_unemploy_csv = pd.read_csv(file_path1, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       5 pandemic_unemploy_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
file_path2 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Post-Pandemic_unemploy.csv')
postpandemic_unemploy_csv = pd.read_csv(file_path2, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

postpandemic_unemploy_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 file_path2 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Post-Pandemic_unemploy.csv')
# ----> 2 postpandemic_unemploy_csv = pd.read_csv(file_path2, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       5 postpandemic_unemploy_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df = unemployment_combined = pd.concat([pre_pandemic_unemploy_csv, pandemic_unemploy_csv, postpandemic_unemploy_csv])


unemployment_combined.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = unemployment_combined = pd.concat([pre_pandemic_unemploy_csv, pandemic_unemploy_csv, postpandemic_unemploy_csv])
#       4 unemployment_combined.head(100)
#
# NameError: name 'pre_pandemic_unemploy_csv' is not defined

# %%
#Plot Umemployment rates

unemployment_combined.plot(figsize = (10,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #Plot Umemployment rates
# ----> 3 unemployment_combined.plot(figsize = (10,20))
#
# NameError: name 'unemployment_combined' is not defined

# %%
# Reading Home Price Index CSV
file_path3 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/prepandemic_sales.csv')
prepandemic_sales_csv = pd.read_csv(file_path3, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

prepandemic_sales_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Reading Home Price Index CSV
#       2 file_path3 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/prepandemic_sales.csv')
# ----> 3 prepandemic_sales_csv = pd.read_csv(file_path3, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       6 prepandemic_sales_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
file_path4 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Pandemic_sales.csv')
pandemic_sales_csv = pd.read_csv(file_path4, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

pandemic_sales_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 file_path4 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Pandemic_sales.csv')
# ----> 2 pandemic_sales_csv = pd.read_csv(file_path4, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       5 pandemic_sales_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
file_path5 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Postpandemic_sales.csv')
postpandemic_sales_csv = pd.read_csv(file_path5, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

postpandemic_sales_csv.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 file_path5 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/Postpandemic_sales.csv')
# ----> 2 postpandemic_sales_csv = pd.read_csv(file_path5, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       5 postpandemic_sales_csv.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
df1 = sales_combined = pd.concat([prepandemic_sales_csv, pandemic_sales_csv, postpandemic_sales_csv])


sales_combined.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1 = sales_combined = pd.concat([prepandemic_sales_csv, pandemic_sales_csv, postpandemic_sales_csv])
#       4 sales_combined.head(100)
#
# NameError: name 'prepandemic_sales_csv' is not defined

# %%
#Plot Home sales price Index

df1.plot(kind = "bar", title = "Home Sales Price Index")
f = plt.figure()
f.set_figwidth(200)
f.set_figheight(20)

print("Plot after re-sizing: ")
plt.plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #Plot Home sales price Index
# ----> 3 df1.plot(kind = "bar", title = "Home Sales Price Index")
#       4 f = plt.figure()
#       5 f.set_figwidth(200)
#
# NameError: name 'df1' is not defined

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from MCForecastTools import MCSimulation

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 5
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 5 from MCForecastTools import MCSimulation
#       7 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'MCForecastTools'

# %%
# Load .env enviroment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
file_path6 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/full unempl.csv')
full_unempl_csv = pd.read_csv(file_path6, index_col="DATE", infer_datetime_format=True, parse_dates=True)
                      

full_unempl_csv.head()

df=full_unempl_csv

mean_days = df.mean()
std_days = df.std()

# Set timeframe to "1Day"
timeframe = "1Day"

# Set number of simulations
num_sims = 1005

# Set start and end datetimes of 3 years from Today
start_date = pd.to_datetime('2023-06-01')
end_date = pd.to_datetime('2026-03-01')
forecast_period = pd.date_range(start=start_date, end=end_date, freq='D')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 file_path6 = Path('/Users/staceysimko/UNCC-VIRT-FIN-PT-05-2023-U-LOLC/Projects/full unempl.csv')
# ----> 2 full_unempl_csv = pd.read_csv(file_path6, index_col="DATE", infer_datetime_format=True, parse_dates=True)
#       5 full_unempl_csv.head()
#       7 df=full_unempl_csv
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
simulation_results = []
for _ in range(num_sims):
    random_days = np.random.normal(len(full_unempl_csv))
    simulation_results.append(random_days)

# %%
# Run Monte Carlo simulations to forecast three years daily returns
forecast_df = pd.DataFrame(simulation_results, index=forecast_period)
mean_duration_forecast = df.mean(axis=0)
std_duration_forecast = df.std(axis=0)

# %%
print("Monte Carlo Simulation Forecast Results:")
print("Forecast Start Date:", start_date)
print("Forecast End Date:", end_date)
print("Mean Duration:")
print(mean_duration_forecast)
print("Standard Deviation of Duration:")
print(std_duration_forecast)

# %%
# Plot the mean duration over time

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(forecast_period, mean_duration_forecast)
plt.xlabel("Date")
plt.ylabel("Mean Duration")
plt.title("Monte Carlo Simulation: Mean Duration over Time")
plt.grid(True)
plt.show()

# Plot the standard deviation of duration over time

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(forecast_period, std_duration_forecast)
plt.xlabel("Date")
plt.ylabel("Standard Deviation of Duration")
plt.title("Monte Carlo Simulation: Standard Deviation of Duration over Time")
plt.grid(True)
plt.show()
